# %% [markdown]
# # Definsi
#
# Regresi Linear Sederhana merupakan metode untuk memperkirakan pengaruh variabel bebas (independen) terhadap variabel terikat (dependen). Dalam model ini banyaknya variabel bebas yang digunakan adalah 1.
#
# # Bentuk Umum
# Bentuk umum Regresi Linear Sederhana adalah sebagai berikut
#
# \begin{equation}
# y = m\cdot x + b
# \end{equation}
#
# dengan :
# <ul>
# <li>𝑦 = variabel dependen</li>
# <li>𝑥 = variabel independen</li>
# <li>𝑚 = slope / kemiringan (angka ini menyatakan perubahan nilai Y saat kenaikan satu satuan nilai X)</li>
# <li>𝑏 = intersep, angka ini menyatakan nilai 𝑦 saat nilai 𝑥 = 0</li>
# </ul>
#
# 𝑚 dan 𝑏 dirumuskan sebagai berikut :
#
# <img src="https://i.stack.imgur.com/JxedC.jpg">

# %% [markdown]
# # Contoh
#
# Sebuah perusahaan DQTech menggunakan model regresi linier untuk memahami hubungan antara pengeluaran iklan (<i>advertising spend</i>) dan pendapatan (<i>revenue</i>). Alasan menggunakan model ini adalah mereka berasumsi bahwa semakin banyak (<i>advertising spend</i>) dikeluarkan perusahaan maka semakin tinggi pula (<i>revenue</i>) yang diperoleh.
#
# Data pengeluaran iklan (<i>advertising spend</i>) dan pendapatan (<i>revenue</i>) disajikan pada tabel berikut :
#
# <table>
#   <tr>
#     <td align="center">advertising_spend</td>
#     <td align="center">revenue</td>
#   </tr>
#   <tr>
#     <td align="center">400</td>
#     <td align="center">551</td>
#   </tr>
#    <tr>
#     <td align="center">380</td>
#     <td align="center">480</td>
#   </tr>
#   <tr>
#     <td align="center">600</td>
#     <td align="center">508</td>
#   </tr>
#   <tr>
#     <td align="center">357</td>
#     <td align="center">512</td>
#   </tr>
#   <tr>
#     <td align="center">623</td>
#     <td align="center">700</td>
#   </tr>
#     <tr>
#     <td align="center">500</td>
#     <td align="center">554</td>
#   </tr>
#     <tr>
#     <td align="center">467</td>
#     <td align="center">800</td>
#   </tr>
# </table>
#
# Perusahaan ingin mengetahui model regresi linearnya agar dapat memprediksi berapa advertisment spend yang harus dikeluarkan jika perusahaan menetapkan target revenue sebesar 𝑅
#
# Jawab :
#
# Misalkan
#
# *   𝑥 = advertisment spend
# *   𝑦 = revenue
#
# Diketahui banyak data 𝑛 = 7
#
# <ol>
#   <li>Hitung Total advertisment spend (𝑥)</li>
#   \begin{equation}
#   \sum_{i=1}^{n}x_i = x_1 + x_2 + ... + x_n
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}x_i = 400 + 380 + ... + 500 + 467
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}x_i = 3327
#   \end{equation}
#
#   <li>Hitung Total pangkat dua dari advertisment spend (𝑥^2)</li>
#   \begin{equation}
#   \sum_{i=1}^{n}(x_i)^2 = (x_1)^2 + (x_2)^2 + ... + (x_n)^2
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}(x_i)^2 = (400)^2 + (380)^2 + ... + (500)^2 + (467)^2
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}(x_i)^2 = 160000 + 144400 + ... + 250000 + 218089
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}(x_i)^2 = 1648067
#   \end{equation}
#
#   <li>Hitung Total revenue (𝑦)</li>
#   \begin{equation}
#   \sum_{i=1}^{n}y_i = y_1 + y_2 + ... + y_n
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}y_i = 551 + 480 + ... + 554 + 800
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}y_i = 4105
#   \end{equation}
#
#   <li>Hitung Total hasil kali dari advertisment spend (𝑥) dan revenue (𝑦)</li>
#   \begin{equation}
#   \sum_{i=1}^{n}x_i\cdot y_i = x_1\cdot y_1 + x_2\cdot y_2 + ... + x_n\cdot y_n
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}x_i\cdot y_i = 400\cdot551 + 380\cdot480 + ... + 467\cdot 800
#   \end{equation}
#   \begin{equation}
#   \sum_{i=1}^{7}x_i\cdot y_i = 1977084
#   \end{equation}
#
#   <li>Hitung slope 𝑚</li>
#   \begin{equation}
#   m = \frac{n\sum_{i=1}^{n}x_i\cdot y_i - \sum_{i=1}^{n}x_i \sum_{i=1}^{n}y_i }{n\sum_{i=1}^{n}(x_i)^2 - (\sum_{i=1}^{n}x_i)^2}
#   \end{equation}
#
#   \begin{equation}
#   m = \frac{7\cdot 1977084 - 3327 \cdot 4105}{7 \cdot 1648067 - (3327)^2}
#   \end{equation}
#
#   \begin{equation}
#   m = 0.3898
#   \end{equation}
#
#   <li>Hitung konstanta 𝑏</li>
#
#   \begin{equation}
#   b = \frac{\sum_{i=1}^{n}y_i - m\sum_{i=1}^{n}x_i}{n}
#   \end{equation}
#
#   \begin{equation}
#   b = \frac{4105 - 0.3898\cdot 3327}{7}
#   \end{equation}
#
#   \begin{equation}
#   b = 401.1562
#   \end{equation}
#
#   <li>Buat Model Regresinya</li>
#   \begin{equation}
#   y = m\cdot x + b
#   \end{equation}
#
#   \begin{equation}
#   y = 0.3898\cdot x + 401.1562
#   \end{equation}
#
#   <li>Interpretasi Model</li>
#   <ol>
#      <li>Nilai intersep/konstanta sebesar 401.1562 artinya saat perusahaan tidak membelanjakan uangnya untuk kebutuhan iklan atau <i>advertisment spend</i> = 0, maka rata-rata perusahaan masih akan mendapatkan revenue sekitar 401.1562 satuan mata uang</li>
#      <li>Koefisien slope sebesar 0.3898 artinya setiap kenaikan uang yang dibelanjakan untuk kebutuhan iklan sebesar 1 satuan, maka rata-rata revenue yang diperoleh perusahaan akan meningkat sekitar 0.3898 poin</li>
#   </ol>
# </ol>
#
# source : https://ujistatistik.com/contoh-soal-regresi-linear-sederhana/

# %% [markdown]
# # Interpretasi Grafik

# %%
# Import library yang akan digunakan
import pandas as pd
import plotly.express as px

# Buat dataframe
df = pd.DataFrame({
    'advertising spend' : [400, 380, 600, 357, 623, 500, 467], 
    'revenue' : [551, 480, 508, 512, 700, 554, 800]
})

# Plot scatter dengan garis regresi
fig = px.scatter(
    df, 
    x="advertising spend", 
    y="revenue", 
    trendline="ols"
)

# Tampilkan grafik
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Soal
#
# Buatlah sebuah fungsi dengan parameter berupa dataX (data dengan tipe data list) dan dataY (data dengan tipe data list) bernama `regresi_linear_sederhana(dataX, dataY)` yang akan mengembalikan nilai (<i>return</i>) dua nilai yakni slope (𝑚) dan intersep (𝑏).
#
#     Contoh :
#     >>> dataX = [400, 380, 600, 357, 623, 500, 467]
#     >>> dataY = [551, 480, 508, 512, 700, 554, 800]
#     >>> m, b = regresi_linear_sederhana(dataX, dataY)
#     >>> print(m)
#     ... 0.3898
#     >>> print(b)
#     ... 401.1562
#
# note : anda tidak diperkenankan menggunakan library apapun untuk menghitung challenge ini. Be native!

# %%
# Selamat bekerja!

def regresi_linear_sederhana(data_x, data_Y):
    #Calculate sum(x)
    Total_study_time = sum(data_X)
    
    #Calculate sum(x**2)
    init1 =[]
    for i in data_X:
        init1.append(i**2)
    x2_Total_study_time = sum(init1)
    
    #Calculate sum(y)
    Total_Test_Score = sum(data_Y)
    
    #Calculate sum(x*y)
    init2 = []
    for i in range(0,len(data_X)):
        init2.append(data_X[i]*data_Y[i])
    mult_study_time_Test_Score = sum(init2)

    #Slope m
    m = (len(data_X)*mult_study_time_Test_Score-Total_study_time*Total_Test_Score)/(len(data_X)*x2_Total_study_time-Total_study_time**2)

    #Konstanta b
    b = (Total_Test_Score-m*Total_study_time)/len(data_X)
    return "Slope", m, "Konstanta", b

# %%
#Example of Regression Model
x = [2, 1.5, 2.5, 6.3, 3, 4, 2, 5.3, 7, 3.5]
y = [76, 79, 74, 80, 78, 82, 75, 85, 81, 82]
regresi_linear_sederhana(x,y)
# Out:
# ('Slope', 1.1456718051628185, 'Kontanta', 74.94955760284594)
